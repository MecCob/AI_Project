# %%
#import library
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from keras.utils import np_utils
import tensorflow as tf
import numpy as np
import cv2
import os

# %%
image_generator = ImageDataGenerator(rescale=1./255, validation_split=0.2)    

train_dataset = image_generator.flow_from_directory(batch_size=10,
                                                 directory='../input/data-money-train',
                                                 shuffle=True,
                                                 target_size=(150, 150), 
                                                 subset="training",
                                                 class_mode='categorical')

validation_dataset = image_generator.flow_from_directory(batch_size=10,
                                                 directory='../input/data-money-train',
                                                 shuffle=True,
                                                 target_size=(150, 150), 
                                                 subset="validation",
                                                 class_mode='categorical')
# Out:
# Found 176 images belonging to 11 classes.
# Found 44 images belonging to 11 classes.

# %%
# X_train.shape, y_train.shape,X_test.shape,y_test.shape
train_dataset.classes
train_dataset.class_indices
# Out:
# {'1000': 0,
#  '10000': 1,
#  '100000': 2,
#  '200': 3,
#  '2000': 4,
#  '20000': 5,
#  '200000': 6,
#  '500': 7,
#  '5000': 8,
#  '50000': 9,
#  '500000': 10}

# %%
import numpy as np  #
import pandas as pd # xu ly mang
import seaborn as sns # do thi
import matplotlib.pyplot as plt # ve do hoa
from sklearn.preprocessing import StandardScaler  # xu ly du lieu , du lieu k dong deu
from sklearn.model_selection import train_test_split # chia du lieu 
from keras.layers import Dense,Activation,Dropout,BatchNormalization,LSTM #  :batch... : chuan cua ANN
from keras.models import Sequential 
from tensorflow.keras.utils import to_categorical #  de dam bao do hcinh xac cao 
from keras import callbacks #
from sklearn .metrics import  precision_score,recall_score, confusion_matrix, classification_report, accuracy_score,f1_score # thu vien cho do luong

# %%
# Tạo mô hinh
from keras.layers import Conv2D, MaxPooling2D
model = Sequential()
model.add(Conv2D(32,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same',input_shape=(150,150,3))) # 32 lần tích chập
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same')) # 64 lần tích chập
model.add(Conv2D(64,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same')) # 128 lần tích chập
model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
# Out:
# 2022-05-20 08:32:25.325025: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
# Dùng CNN tách biên và giờ quay trở loại ANN để phân loại
from keras.layers.convolutional import Conv2D, MaxPooling2D

from keras.layers import Dense, Activation, Flatten


model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(11,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 150, 150, 32)      9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 75, 75, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 37, 37, 128)       73856
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 37, 37, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 41472)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               5308544
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 11)                1419
# =================================================================
# Total params: 5,596,971
# Trainable params: 5,596,971
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import SGD
opt = SGD(learning_rate = 0.001, momentum = 0.9)
model .compile(optimizer = opt, loss ='categorical_crossentropy', metrics = ['accuracy'])
history=model.fit(train_dataset,batch_size=32,epochs=70,verbose=1,validation_data=validation_dataset)
# Out:
# 2022-05-20 08:32:25.903272: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/70
# 18/18 [==============================] - 13s 669ms/step - loss: 2.7759 - accuracy: 0.1080 - val_loss: 2.4306 - val_accuracy: 0.1591
# Epoch 2/70
# 18/18 [==============================] - 12s 682ms/step - loss: 2.4639 - accuracy: 0.1136 - val_loss: 2.3775 - val_accuracy: 0.0909
# Epoch 3/70
# 18/18 [==============================] - 12s 640ms/step - loss: 2.3635 - accuracy: 0.1307 - val_loss: 2.3380 - val_accuracy: 0.1818
# Epoch 4/70
# 18/18 [==============================] - 12s 632ms/step - loss: 2.2856 - accuracy: 0.2784 - val_loss: 2.2201 - val_accuracy: 0.3182
# Epoch 26/70
# 18/18 [==============================] - 12s 662ms/step - loss: 0.1694 - accuracy: 0.9489 - val_loss: 1.3017 - val_accuracy: 0.7273
# Epoch 27/70
# 18/18 [==============================] - 11s 634ms/step - loss: 0.0614 - accuracy: 0.9886 - val_loss: 1.4367 - val_accuracy: 0.7273
# Epoch 28/70
# 18/18 [==============================] - 11s 629ms/step - loss: 0.0432 - accuracy: 0.9886 - val_loss: 1.1303 - val_accuracy: 0.7500
# Epoch 29/70
# 18/18 [==============================] - 12s 670ms/step - loss: 0.0946 - accuracy: 0.9659 - val_loss: 2.1232 - val_accuracy: 0.6818
# Epoch 30/70
# 18/18 [==============================] - 12s 641ms/step - loss: 0.1026 - accuracy: 0.9716 - val_loss: 1.8818 - val_accuracy: 0.6818
# Epoch 31/70
# 18/18 [==============================] - 11s 630ms/step - loss: 0.0972 - accuracy: 0.9830 - val_loss: 1.2051 - val_accuracy: 0.7955
# Epoch 32/70
# 18/18 [==============================] - 11s 631ms/step - loss: 0.0255 - accuracy: 0.9886 - val_loss: 1.3372 - val_accuracy: 0.7500
# Epoch 33/70
# 18/18 [==============================] - 12s 664ms/step - loss: 0.0239 - accuracy: 0.9886 - val_loss: 1.2699 - val_accuracy: 0.7955
# Epoch 34/70
# 18/18 [==============================] - 12s 638ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 1.3685 - val_accuracy: 0.7955
# Epoch 35/70
# 18/18 [==============================] - 12s 640ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 1.5326 - val_accuracy: 0.6818
# Epoch 36/70
# 18/18 [==============================] - 12s 651ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 1.4645 - val_accuracy: 0.7273
# Epoch 37/70
# 18/18 [==============================] - 12s 679ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.5317 - val_accuracy: 0.7955
# Epoch 38/70
# 18/18 [==============================] - 12s 648ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 1.6111 - val_accuracy: 0.7727
# Epoch 39/70
# 18/18 [==============================] - 12s 652ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.6341 - val_accuracy: 0.7955
# Epoch 40/70
# 18/18 [==============================] - 12s 658ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 1.8866 - val_accuracy: 0.7500
# Epoch 41/70
# 18/18 [==============================] - 12s 635ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.7358 - val_accuracy: 0.7500
# Epoch 42/70
# 18/18 [==============================] - 12s 653ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.7059 - val_accuracy: 0.7500
# Epoch 43/70
# 18/18 [==============================] - 12s 668ms/step - loss: 0.0090 - accuracy: 0.9943 - val_loss: 1.8134 - val_accuracy: 0.7500
# Epoch 44/70
# 18/18 [==============================] - 12s 651ms/step - loss: 0.0277 - accuracy: 0.9943 - val_loss: 2.1875 - val_accuracy: 0.6364
# Epoch 45/70
# 18/18 [==============================] - 12s 691ms/step - loss: 0.0553 - accuracy: 0.9886 - val_loss: 1.8092 - val_accuracy: 0.6591
# Epoch 46/70
# 18/18 [==============================] - 12s 640ms/step - loss: 0.0346 - accuracy: 0.9943 - val_loss: 1.5208 - val_accuracy: 0.7273
# Epoch 47/70
# 18/18 [==============================] - 12s 688ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.5510 - val_accuracy: 0.7500
# Epoch 48/70
# 18/18 [==============================] - 12s 642ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 1.4906 - val_accuracy: 0.7500
# Epoch 49/70
# 18/18 [==============================] - 13s 693ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 1.5566 - val_accuracy: 0.7500
# Epoch 50/70
# 18/18 [==============================] - 12s 632ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.6800 - val_accuracy: 0.7273
# Epoch 51/70
# 18/18 [==============================] - 12s 646ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 1.7386 - val_accuracy: 0.7500
# Epoch 52/70
# 18/18 [==============================] - 12s 639ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.7592 - val_accuracy: 0.7500
# Epoch 53/70
# 18/18 [==============================] - 12s 646ms/step - loss: 5.6903e-04 - accuracy: 1.0000 - val_loss: 1.7814 - val_accuracy: 0.7500
# Epoch 54/70
# 18/18 [==============================] - 12s 640ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.7871 - val_accuracy: 0.7500
# Epoch 55/70
# 18/18 [==============================] - 12s 644ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.7452 - val_accuracy: 0.7500
# Epoch 56/70
# 18/18 [==============================] - 12s 680ms/step - loss: 8.8167e-04 - accuracy: 1.0000 - val_loss: 1.7979 - val_accuracy: 0.7500
# Epoch 57/70
# 18/18 [==============================] - 12s 639ms/step - loss: 7.5943e-04 - accuracy: 1.0000 - val_loss: 1.8275 - val_accuracy: 0.7500
# Epoch 58/70
# 18/18 [==============================] - 12s 665ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.8178 - val_accuracy: 0.7727
# Epoch 59/70
# 18/18 [==============================] - 12s 676ms/step - loss: 0.0249 - accuracy: 0.9943 - val_loss: 1.7172 - val_accuracy: 0.7727
# Epoch 60/70
# 18/18 [==============================] - 12s 642ms/step - loss: 0.0445 - accuracy: 0.9886 - val_loss: 1.8012 - val_accuracy: 0.7045
# Epoch 61/70
# 18/18 [==============================] - 12s 655ms/step - loss: 0.0110 - accuracy: 0.9943 - val_loss: 1.6313 - val_accuracy: 0.7273
# Epoch 62/70
# 18/18 [==============================] - 11s 641ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 1.5001 - val_accuracy: 0.7273
# Epoch 63/70
# 18/18 [==============================] - 12s 641ms/step - loss: 0.0308 - accuracy: 0.9943 - val_loss: 1.4028 - val_accuracy: 0.7727
# Epoch 64/70
# 18/18 [==============================] - 11s 631ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 1.3051 - val_accuracy: 0.7727
# Epoch 65/70
# 18/18 [==============================] - 12s 644ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.2911 - val_accuracy: 0.7727
# Epoch 66/70
# 18/18 [==============================] - 12s 666ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.3064 - val_accuracy: 0.7955
# Epoch 67/70
# 18/18 [==============================] - 12s 649ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 1.2638 - val_accuracy: 0.7727
# Epoch 68/70
# 18/18 [==============================] - 12s 667ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.3373 - val_accuracy: 0.7500
# Epoch 69/70
# 18/18 [==============================] - 12s 639ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 1.2909 - val_accuracy: 0.7727
# Epoch 70/70
# 18/18 [==============================] - 11s 627ms/step - loss: 0.0308 - accuracy: 0.9886 - val_loss: 1.5702 - val_accuracy: 0.6818

# %%
# vẽ lại quá trình học
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend(['train','Validation'])
plt.show()

# %%
#in sai so va do chinh xac
score = model.evaluate(validation_dataset,verbose=0)
print('Sai số : ',score[0])
print('Độ chính xác ',score[1])
# Out:
# Sai số :  1.5701642036437988
# Độ chính xác  0.6818181872367859

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/data-money-train/200/200 (1).png"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq=np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("1k")
if(kq==1):
    print("10k")
if(kq==2):
    print("100k")
if(kq==3):
    print("200")
if(kq==4):
    print("2k")
if(kq==5):
    print("20k")
if(kq==6):
    print("200k")
if(kq==7):
    print("500")
if(kq==8):
    print("5k")
if(kq==9):
    print("50k")
if(kq==10):
    print("500k")
# Out:
# 200k
