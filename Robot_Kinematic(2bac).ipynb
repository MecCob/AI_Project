# %%
#import libraries
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score,recall_score,confusion_matrix,classification_report,accuracy_score,f1_score
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, BatchNormalization, LSTM,Conv2D, MaxPooling2D, Flatten,LeakyReLU
from tensorflow.keras.optimizers import RMSprop,SGD
from keras import callbacks
from keras.callbacks import EarlyStopping

# %%
data_robot = []
l1 = 50
l2 = 40
for tt1 in range (-60,60):
  for tt2 in range (-40,40):
    px = l1*np.cos(np.radians(tt1)) + l2*np.cos(np.radians(tt1 + tt2))
    py = l1*np.sin(np.radians(tt1)) + l2*np.sin(np.radians(tt1 + tt2))
    data_robot.append([tt1,tt2,px,py])
data = pd.DataFrame(data_robot,columns=['tt1','tt2','Px','Py'])
data
# Out:
#       tt1  tt2         Px         Py
# 0     -60  -40  18.054073 -82.693580
# 1     -60  -39  18.742621 -82.808804
# 2     -60  -38  19.433076 -82.911993
# 3     -60  -37  20.125226 -83.003116
# 4     -60  -36  20.818861 -83.082146
# ...   ...  ...        ...        ...
# 9595   59   35  22.961645  82.760927
# 9596   59   36  22.265674  82.706153
# 9597   59   37  21.570765  82.639241
# 9598   59   38  20.877130  82.560211
# 9599   59   39  20.184980  82.469088
#
# [9600 rows x 4 columns]

# %%
Y_df=data.drop(['Px','Py'],axis =1)
X_df=data.drop(['tt1','tt2'],axis =1)
print(X_df.shape,Y_df.shape)
# Out:
# (9600, 2) (9600, 2)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X_df,Y_df,test_size=0.2,random_state =7)
print(X_train.shape,Y_train.shape,X_test.shape,Y_test.shape)
# Out:
# (7680, 2) (7680, 2) (1920, 2) (1920, 2)

# %%
# Create model
model = Sequential()
model.add(Dense(64,kernel_initializer='normal',activation='relu',input_shape=(2,)))
model.add(Dense(64,activation ='relu'))
model.add(Dense(64,activation ='relu'))
model.add(Dense(2))
model.summary()

opt = SGD(learning_rate=0.001,momentum=0.1) #toc do hoc 0.01, momen dong luong 0.9 'Ftrl'
model.compile(loss='mse',optimizer=opt,metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                192
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dense_3 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 8,642
# Trainable params: 8,642
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile model
model.compile(loss='mse', optimizer=RMSprop(), metrics = ['accuracy'])

# %%
# Train model
history = model.fit(X_train, Y_train, batch_size = 128, epochs=50,verbose=1,validation_split=0.2, callbacks=[EarlyStopping(monitor='val_loss', patience=20)])
# Out:
# Epoch 1/50
# 48/48 [==============================] - 6s 15ms/step - loss: 399.1671 - accuracy: 0.7542 - val_loss: 293.1809 - val_accuracy: 0.7415
# Epoch 2/50
# 48/48 [==============================] - 0s 10ms/step - loss: 278.8420 - accuracy: 0.7624 - val_loss: 284.6853 - val_accuracy: 0.7467
# Epoch 3/50
# 48/48 [==============================] - 0s 5ms/step - loss: 273.8976 - accuracy: 0.7612 - val_loss: 281.4942 - val_accuracy: 0.7480
# Epoch 4/50
# 48/48 [==============================] - 0s 4ms/step - loss: 272.8752 - accuracy: 0.7609 - val_loss: 280.3072 - val_accuracy: 0.7474
# Epoch 5/50
# 48/48 [==============================] - 0s 5ms/step - loss: 272.7852 - accuracy: 0.7637 - val_loss: 280.4448 - val_accuracy: 0.7448
# Epoch 25/50
# 48/48 [==============================] - 0s 5ms/step - loss: 271.1082 - accuracy: 0.7637 - val_loss: 277.3404 - val_accuracy: 0.7493
# Epoch 26/50
# 48/48 [==============================] - 0s 4ms/step - loss: 270.9217 - accuracy: 0.7607 - val_loss: 276.8410 - val_accuracy: 0.7480
# Epoch 27/50
# 48/48 [==============================] - 0s 5ms/step - loss: 271.1514 - accuracy: 0.7612 - val_loss: 280.5619 - val_accuracy: 0.7474
# Epoch 28/50
# 48/48 [==============================] - 0s 4ms/step - loss: 271.1585 - accuracy: 0.7604 - val_loss: 278.5187 - val_accuracy: 0.7461
# Epoch 29/50
# 48/48 [==============================] - 0s 4ms/step - loss: 271.1473 - accuracy: 0.7599 - val_loss: 278.3138 - val_accuracy: 0.7461
# Epoch 30/50
# 48/48 [==============================] - 0s 4ms/step - loss: 270.4638 - accuracy: 0.7632 - val_loss: 282.3790 - val_accuracy: 0.7467
# Epoch 31/50
# 48/48 [==============================] - 0s 5ms/step - loss: 271.1437 - accuracy: 0.7603 - val_loss: 277.4142 - val_accuracy: 0.7480
# Epoch 32/50
# 48/48 [==============================] - 0s 4ms/step - loss: 270.7301 - accuracy: 0.7611 - val_loss: 277.0175 - val_accuracy: 0.7493
# Epoch 33/50
# 48/48 [==============================] - 0s 4ms/step - loss: 270.6707 - accuracy: 0.7611 - val_loss: 280.2484 - val_accuracy: 0.7461
# Epoch 34/50
# 48/48 [==============================] - 0s 5ms/step - loss: 270.9013 - accuracy: 0.7604 - val_loss: 277.6508 - val_accuracy: 0.7480
# Epoch 35/50
# 48/48 [==============================] - 0s 5ms/step - loss: 270.5817 - accuracy: 0.7638 - val_loss: 278.2083 - val_accuracy: 0.7480
# Epoch 36/50
# 48/48 [==============================] - 0s 5ms/step - loss: 270.3944 - accuracy: 0.7609 - val_loss: 277.0233 - val_accuracy: 0.7500
# Epoch 37/50
# 48/48 [==============================] - 0s 4ms/step - loss: 270.7518 - accuracy: 0.7627 - val_loss: 276.9356 - val_accuracy: 0.7467
# Epoch 38/50
# 48/48 [==============================] - 0s 4ms/step - loss: 270.6789 - accuracy: 0.7611 - val_loss: 277.6387 - val_accuracy: 0.7467
# Epoch 39/50
# 48/48 [==============================] - 0s 4ms/step - loss: 270.4263 - accuracy: 0.7611 - val_loss: 277.8160 - val_accuracy: 0.7474
# Epoch 40/50
# 48/48 [==============================] - 0s 4ms/step - loss: 270.5221 - accuracy: 0.7616 - val_loss: 277.2377 - val_accuracy: 0.7474
# Epoch 41/50
# 48/48 [==============================] - 0s 5ms/step - loss: 270.8294 - accuracy: 0.7612 - val_loss: 277.3842 - val_accuracy: 0.7467
# Epoch 42/50
# 48/48 [==============================] - 0s 4ms/step - loss: 270.6702 - accuracy: 0.7629 - val_loss: 277.9371 - val_accuracy: 0.7493

# %%
test = np.array([[70,10],[30,50]])
y_predict = model.predict(test)
print(y_predict)
# Out:
# [[ 7.137626   0.1866142]
#  [33.862988  13.000661 ]]
